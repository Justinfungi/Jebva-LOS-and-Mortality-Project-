# %% [markdown]
# # Libraries

# %% [markdown]
# ! pip install numpy pandas sklearn

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.impute import SimpleImputer

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Import data

# %% [markdown]
# ## X

# %%
# For training the model


# For cross validation
X_valid = pd.read_csv("../X/X_valid.csv", index_col=[0], header=[0, 1, 2])

# For prediction
X_test = pd.read_csv("../X/X_test.csv", index_col=[0], header=[0, 1, 2])

# %%
X_test = pd.read_csv("../X/X_train.csv" , index_col=[0], header=[1, 2])

# %% [markdown]
# ## Task 1

# %%
y_train_t1 = pd.read_csv("../Task1/Y_train.csv")
y_valid_t1 = pd.read_csv("../Task1/Y_valid.csv")

# %% [markdown]
# ## Task 2

# %%
y_train_t2 = pd.read_csv("../Task2/Y_train.csv")
y_valid_t2 = pd.read_csv("../Task2/Y_valid.csv")

# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# ## Data Version 1: Mean

# %%
li=[] # Find the positions of the columns with means of the particular feature after 24 hours
for i in range(47, 7488, 72):
    li.append(i)
#print(li)

headlist=list(X_train.columns.values)[1:]
head=[]
for i in li:
    head.append(headlist[i][0])

dx_train = pd. DataFrame(X_train)
X_train_mean= dx_train.iloc[:,li]
X_train_mean.columns=head

dx_valid = pd. DataFrame(X_valid)
X_valid_mean= dx_valid.iloc[:,li]
X_valid_mean.columns=head

x_test=X_test.values
dx_test = pd. DataFrame(x_test)
X_test_mean= dx_test.iloc[:,li]
X_test_mean.columns=head

# %%
X_valid_mean
# Out:
#                      alanine aminotransferase   albumin  albumin ascites  \
# 4_185777_294638                     -0.255529 -0.539814              0.0
# 21_109451_217847                    -0.149653  0.000000              0.0
# 25_129635_203487                    -0.256599  0.036202              0.0
# 114_178393_258626                    0.000000  0.000000              0.0
# 129_164174_238431                   -0.253390 -0.107802              0.0
# ...                                       ...       ...              ...
# 99823_179720_296047                 -0.229862  0.000000              0.0
# 99868_177777_231346                 -0.269432  2.628276              0.0
# 99899_188409_245756                 -0.268363 -0.395810              0.0
# 99901_131711_226541                  0.000000  0.000000              0.0
# 99936_107913_213906                 -0.266224  0.000000              0.0
#
#                      albumin pleural  albumin urine  alkaline phosphate  \
# 4_185777_294638                  0.0            0.0            4.967764
# 21_109451_217847                 0.0            0.0           -0.325534
# 25_129635_203487                 0.0            0.0           -0.678421
# 114_178393_258626                0.0            0.0            0.000000
# 129_164174_238431                0.0            0.0           -0.380889
# ...                              ...            ...                 ...
# 99823_179720_296047              0.0            0.0           -0.512357
# 99868_177777_231346              0.0            0.0           -0.588469
# 99899_188409_245756              0.0            0.0            0.657012
# 99901_131711_226541              0.0            0.0            0.000000
# 99936_107913_213906              0.0            0.0           -0.318615
#
#                      anion gap  asparate aminotransferase  basophils  \
# 4_185777_294638       0.152716                  -0.230571  -0.742403
# 21_109451_217847      3.052859                  -0.064531   0.000000
# 25_129635_203487     -1.780713                  -0.225827  -0.484272
# 114_178393_258626     0.000000                   0.000000   0.000000
# 129_164174_238431    -0.572320                  -0.264570  -0.226141
# ...                        ...                        ...        ...
# 99823_179720_296047  -1.297356                  -0.219502   0.000000
# 99868_177777_231346  -1.539034                  -0.270104   0.031990
# 99899_188409_245756   0.636073                  -0.259035   0.000000
# 99901_131711_226541  -0.572320                   0.000000   0.000000
# 99936_107913_213906  -0.572320                  -0.266151   0.000000
#
#                      bicarbonate  ...  tidal volume set  \
# 4_185777_294638        -0.480340  ...          0.000000
# 21_109451_217847       -1.766315  ...          0.000000
# 25_129635_203487        0.162647  ...          0.000000
# 114_178393_258626       0.591306  ...          2.117668
# 129_164174_238431       0.162647  ...          0.440628
# ...                          ...  ...               ...
# 99823_179720_296047     1.662951  ...          0.000000
# 99868_177777_231346    -1.123327  ...          0.000000
# 99899_188409_245756     0.162647  ...         -1.236412
# 99901_131711_226541     2.734597  ...          0.000000
# 99936_107913_213906     1.019964  ...          0.000000
#
#                      tidal volume spontaneous  total protein  \
# 4_185777_294638                      0.000000            0.0
# 21_109451_217847                     0.000000            0.0
# 25_129635_203487                     0.000000            0.0
# 114_178393_258626                    0.000000            0.0
# 129_164174_238431                    0.457595            0.0
# ...                                       ...            ...
# 99823_179720_296047                  0.000000            0.0
# 99868_177777_231346                  0.000000            0.0
# 99899_188409_245756                 -1.235133            0.0
# 99901_131711_226541                  0.000000            0.0
# 99936_107913_213906                  0.000000            0.0
#
#                      total protein urine  troponin-i  troponin-t  venous pvo2  \
# 4_185777_294638                      0.0         0.0    0.000000     0.000000
# 21_109451_217847                     0.0         0.0    0.973905    -0.794602
# 25_129635_203487                     0.0         0.0    0.114525    -0.854332
# 114_178393_258626                    0.0         0.0    0.000000     0.000000
# 129_164174_238431                    0.0         0.0    0.000000     0.000000
# ...                                  ...         ...         ...          ...
# 99823_179720_296047                  0.0         0.0    0.000000     0.000000
# 99868_177777_231346                  0.0         0.0    0.000000     0.000000
# 99899_188409_245756                  0.0         0.0   -0.335202     0.000000
# 99901_131711_226541                  0.0         0.0    0.000000     0.000000
# 99936_107913_213906                  0.0         0.0   -0.366371     0.000000
#
#                        weight  white blood cell count  \
# 4_185777_294638     -1.220127               -0.265520
# 21_109451_217847    -0.705746                0.797607
# 25_129635_203487     0.785960               -0.088332
# 114_178393_258626    0.854544                0.499185
# 129_164174_238431   -0.431409               -0.274846
# ...                       ...                     ...
# 99823_179720_296047 -0.822857                0.862887
# 99868_177777_231346 -1.304283               -0.023052
# 99899_188409_245756 -0.908408                0.070204
# 99901_131711_226541  0.293011               -0.302823
# 99936_107913_213906 -0.692886               -0.461359
#
#                      white blood cell count urine
# 4_185777_294638                          0.000000
# 21_109451_217847                         0.000000
# 25_129635_203487                         0.000000
# 114_178393_258626                       -0.249199
# 129_164174_238431                        0.000000
# ...                                           ...
# 99823_179720_296047                      0.000000
# 99868_177777_231346                      0.000000
# 99899_188409_245756                      0.501123
# 99901_131711_226541                      0.000000
# 99936_107913_213906                      0.000000
#
# [2394 rows x 104 columns]

# %%
# Impute the 0 with mean

imp = SimpleImputer(missing_values=0, strategy='mean')
X_train_mean = pd.DataFrame(imp.fit_transform(X_train_mean))
X_train_mean.columns=head
X_valid_mean = pd.DataFrame(imp.fit_transform(X_valid_mean))
X_valid_mean
# Out:
#            0         1         2         3         4         5         6    \
# 0    -0.255529 -0.539814 -0.086628 -0.388407  0.502387  4.967764  0.152716
# 1    -0.149653  0.014564 -0.086628 -0.388407  0.502387 -0.325534  3.052859
# 2    -0.256599  0.036202 -0.086628 -0.388407  0.502387 -0.678421 -1.780713
# 3    -0.121652  0.014564 -0.086628 -0.388407  0.502387 -0.083872 -0.275658
# 4    -0.253390 -0.107802 -0.086628 -0.388407  0.502387 -0.380889 -0.572320
# ...        ...       ...       ...       ...       ...       ...       ...
# 2389 -0.229862  0.014564 -0.086628 -0.388407  0.502387 -0.512357 -1.297356
# 2390 -0.269432  2.628276 -0.086628 -0.388407  0.502387 -0.588469 -1.539034
# 2391 -0.268363 -0.395810 -0.086628 -0.388407  0.502387  0.657012  0.636073
# 2392 -0.121652  0.014564 -0.086628 -0.388407  0.502387 -0.083872 -0.572320
# 2393 -0.266224  0.014564 -0.086628 -0.388407  0.502387 -0.318615 -0.572320
#
#            7         8         9    ...       92        93        94   \
# 0    -0.230571 -0.742403 -0.480340  ... -0.125717  0.014241 -0.521822
# 1    -0.064531 -0.027579 -1.766315  ... -0.125717  0.014241 -0.521822
# 2    -0.225827 -0.484272  0.162647  ... -0.125717  0.014241 -0.521822
# 3    -0.124605 -0.027579  0.591306  ...  2.117668  0.014241 -0.521822
# 4    -0.264570 -0.226141  0.162647  ...  0.440628  0.457595 -0.521822
# ...        ...       ...       ...  ...       ...       ...       ...
# 2389 -0.219502 -0.027579  1.662951  ... -0.125717  0.014241 -0.521822
# 2390 -0.270104  0.031990 -1.123327  ... -0.125717  0.014241 -0.521822
# 2391 -0.259035 -0.027579  0.162647  ... -1.236412 -1.235133 -0.521822
# 2392 -0.124605 -0.027579  2.734597  ... -0.125717  0.014241 -0.521822
# 2393 -0.266151 -0.027579  1.019964  ... -0.125717  0.014241 -0.521822
#
#            95        96        97        98        99        100       101
# 0    -0.094843  0.089434  0.019497 -0.051496 -1.220127 -0.265520 -0.028296
# 1    -0.094843  0.089434  0.973905 -0.794602 -0.705746  0.797607 -0.028296
# 2    -0.094843  0.089434  0.114525 -0.854332  0.785960 -0.088332 -0.028296
# 3    -0.094843  0.089434  0.019497 -0.051496  0.854544  0.499185 -0.249199
# 4    -0.094843  0.089434  0.019497 -0.051496 -0.431409 -0.274846 -0.028296
# ...        ...       ...       ...       ...       ...       ...       ...
# 2389 -0.094843  0.089434  0.019497 -0.051496 -0.822857  0.862887 -0.028296
# 2390 -0.094843  0.089434  0.019497 -0.051496 -1.304283 -0.023052 -0.028296
# 2391 -0.094843  0.089434 -0.335202 -0.051496 -0.908408  0.070204  0.501123
# 2392 -0.094843  0.089434  0.019497 -0.051496  0.293011 -0.302823 -0.028296
# 2393 -0.094843  0.089434 -0.366371 -0.051496 -0.692886 -0.461359 -0.028296
#
# [2394 rows x 102 columns]

# %% [markdown]
# ## Data version 2: No feature containing 70% 0 value (call is"nozero")

# %%
# Eliminate feature containing 70% 0 value
import copy
X_train_mean_nozero=copy.deepcopy(X_train_mean)
X_valid_mean_nozero=copy.deepcopy(X_valid_mean)
for i in X_train_mean.columns:
    if (X_train_mean_nozero[i] == 0).sum()> 12000:
        X_train_mean_nozero.drop(i, axis=1, inplace=True)

headnozero=list(X_train_mean_nozero.columns.values)
X_valid_mean_nozero = X_valid_mean_nozero[X_train_mean_nozero.columns]

# %%
X_valid_mean_nozero
# Out:
#       alanine aminotransferase   albumin  alkaline phosphate  anion gap  \
# 0                    -0.255529 -0.539814            4.967764   0.152716
# 1                    -0.149653  0.014564           -0.325534   3.052859
# 2                    -0.256599  0.036202           -0.678421  -1.780713
# 3                    -0.121652  0.014564           -0.083872  -0.275658
# 4                    -0.253390 -0.107802           -0.380889  -0.572320
# ...                        ...       ...                 ...        ...
# 2389                 -0.229862  0.014564           -0.512357  -1.297356
# 2390                 -0.269432  2.628276           -0.588469  -1.539034
# 2391                 -0.268363 -0.395810            0.657012   0.636073
# 2392                 -0.121652  0.014564           -0.083872  -0.572320
# 2393                 -0.266224  0.014564           -0.318615  -0.572320
#
#       asparate aminotransferase  basophils  bicarbonate  bilirubin  \
# 0                     -0.230571  -0.742403    -0.480340  -0.123166
# 1                     -0.064531  -0.027579    -1.766315  -0.395779
# 2                     -0.225827  -0.484272     0.162647  -0.395779
# 3                     -0.124605  -0.027579     0.591306  -0.100799
# 4                     -0.264570  -0.226141     0.162647  -0.371366
# ...                         ...        ...          ...        ...
# 2389                  -0.219502  -0.027579     1.662951  -0.395779
# 2390                  -0.270104   0.031990    -1.123327  -0.420192
# 2391                  -0.259035  -0.027579     0.162647  -0.420192
# 2392                  -0.124605  -0.027579     2.734597  -0.100799
# 2393                  -0.266151  -0.027579     1.019964  -0.371366
#
#       blood urea nitrogen   calcium  ...  respiratory rate set    sodium  \
# 0               -0.740778 -0.393593  ...             -0.150287  0.506401
# 1                3.521754  0.224186  ...             -0.150287 -0.047833
# 2                0.371187 -0.187666  ...             -0.150287  0.136911
# 3               -0.416455  0.021369  ...             -0.605672 -0.047833
# 4               -0.926105 -0.805445  ...             -0.369343  1.060635
# ...                   ...       ...  ...                   ...       ...
# 2389            -0.972437 -0.462235  ...             -0.150287 -0.232578
# 2390            -0.972437 -0.119024  ...             -0.150287 -0.232578
# 2391             0.695510  0.018260  ...              0.457809 -1.895281
# 2392             1.158829  0.567397  ...             -0.150287 -1.341047
# 2393            -0.462786  0.292828  ...             -0.150287  0.321656
#
#       systolic blood pressure  temperature  tidal volume observed  \
# 0                   -0.014434    -0.353389              -0.120505
# 1                   -0.295004    -0.881225              -0.120505
# 2                   -0.341766    -0.221444              -0.120505
# 3                   -0.435290     1.625830               1.559423
# 4                   -0.809384     0.240389               0.480455
# ...                       ...          ...                    ...
# 2389                 0.406422    -0.353408              -0.120505
# 2390                 0.406422    -0.881210              -0.120505
# 2391                -0.575575    -0.683284              -0.986943
# 2392                -0.902907    -0.815234              -0.120505
# 2393                 1.575465     0.504270              -0.120505
#
#       tidal volume set  tidal volume spontaneous  troponin-t    weight  \
# 0            -0.125717                  0.014241    0.019497 -1.220127
# 1            -0.125717                  0.014241    0.973905 -0.705746
# 2            -0.125717                  0.014241    0.114525  0.785960
# 3             2.117668                  0.014241    0.019497  0.854544
# 4             0.440628                  0.457595    0.019497 -0.431409
# ...                ...                       ...         ...       ...
# 2389         -0.125717                  0.014241    0.019497 -0.822857
# 2390         -0.125717                  0.014241    0.019497 -1.304283
# 2391         -1.236412                 -1.235133   -0.335202 -0.908408
# 2392         -0.125717                  0.014241    0.019497  0.293011
# 2393         -0.125717                  0.014241   -0.366371 -0.692886
#
#       white blood cell count
# 0                  -0.265520
# 1                   0.797607
# 2                  -0.088332
# 3                   0.499185
# 4                  -0.274846
# ...                      ...
# 2389                0.862887
# 2390               -0.023052
# 2391                0.070204
# 2392               -0.302823
# 2393               -0.461359
#
# [2394 rows x 61 columns]

# %%
# Impute the 0 with mean

imp = SimpleImputer(missing_values=0, strategy='mean')
X_train_mean_nozero = pd.DataFrame(imp.fit_transform(X_train_mean_nozero))
X_train_mean_nozero.columns=headnozero
X_valid_mean_nozero = pd.DataFrame(imp.fit_transform(X_valid_mean_nozero))
X_valid_mean_nozero.columns=headnozero
X_train_mean_nozero
# Out:
#        alanine aminotransferase   albumin  alkaline phosphate  anion gap  \
# 0                     -0.254460 -1.979855           -0.318615   0.152716
# 1                     -0.256599 -0.251806           -0.422405   1.361109
# 2                     -0.269432  0.037669           -0.367050  -0.330641
# 3                     -0.138009  0.037669           -0.068373  -0.088963
# 4                     -0.138009  0.037669           -0.068373  -0.813998
# ...                         ...       ...                 ...        ...
# 16755                 -0.138009  1.044231           -0.068373  -0.813998
# 16756                 -0.138009  0.037669           -0.068373  -0.088963
# 16757                 -0.260876  1.044231           -0.297857  -0.330641
# 16758                 -0.138009  0.037669           -0.068373  -1.055677
# 16759                 -0.243765  0.037669           -0.207906  -1.297356
#
#        asparate aminotransferase  basophils  bicarbonate  bilirubin  \
# 0                      -0.226618   0.004223    -1.337656  -0.298127
# 1                      -0.254291  -0.742403    -1.123327  -0.444605
# 2                      -0.271686   2.097036     0.591306  -0.395779
# 3                      -0.142030   0.004223     0.591306  -0.111300
# 4                      -0.142030   0.004223     0.376977  -0.111300
# ...                          ...        ...          ...        ...
# 16755                  -0.142030   0.290121     0.376977  -0.111300
# 16756                  -0.142030  -0.742403    -2.409302  -0.111300
# 16757                  -0.261407   0.004223     1.448622  -0.151648
# 16758                  -0.142030   0.004223     0.591306  -0.111300
# 16759                  -0.221874   0.004223     1.877280   0.361027
#
#        blood urea nitrogen   calcium  ...  respiratory rate set    sodium  \
# 0                 0.741842 -1.080013  ...              0.339645  0.136911
# 1                 1.807475 -0.256308  ...             -0.111250 -0.786812
# 2                -0.416455  0.636039  ...             -0.133014 -0.417323
# 3                -0.323791  0.910607  ...             -0.111250  0.691146
# 4                 0.602846  0.430112  ...              0.103316  1.245380
# ...                    ...       ...  ...                   ...       ...
# 16755            -0.184795  0.361470  ...             -0.111250 -0.047833
# 16756            -0.370123 -0.599519  ...             -0.111250  0.321656
# 16757             0.093196  0.361470  ...             -0.111250 -0.971557
# 16758            -0.370123 -0.462235  ...             -0.111250  1.430125
# 16759            -0.601782 -0.050382  ...             -0.369343 -0.602068
#
#        systolic blood pressure  temperature  tidal volume observed  \
# 0                    -0.739241     0.517466               0.336592
# 1                     2.043083     0.438275              -0.055911
# 2                     0.874039     0.702221               1.199767
# 3                    -1.277001    -0.617335              -0.055911
# 4                     1.154610     0.438275               0.379751
# ...                        ...          ...                    ...
# 16755                 0.406422    -2.002789              -0.055911
# 16756                -0.341766     0.042444              -0.055911
# 16757                -0.856145    -0.815234              -0.055911
# 16758                 1.809274     0.372320              -0.055911
# 16759                 1.575465     0.174394              -1.806959
#
#        tidal volume set  tidal volume spontaneous  troponin-t    weight  \
# 0              0.440628                  0.023318   -0.041759  1.026004
# 1             -0.044896                  0.023318   -0.041759  0.007582
# 2              1.279148                  0.023318   -0.041759  0.007582
# 3             -0.044896                  0.023318   -0.041759  0.007582
# 4              0.440628                 -1.333059   -0.317391  0.007582
# ...                 ...                       ...         ...       ...
# 16755         -0.044896                  0.023318   -0.366371  0.584864
# 16756         -0.044896                  0.023318   -0.361918  0.973702
# 16757         -0.044896                  0.023318   -0.041759 -0.392830
# 16758         -0.044896                  0.023318   -0.041759  0.781214
# 16759         -0.817152                 -0.406955   -0.366371 -0.608981
#
#        white blood cell count
# 0                    1.105354
# 1                   -0.181589
# 2                    0.107507
# 3                    0.023576
# 4                   -0.442708
# ...                       ...
# 16755               -0.162937
# 16756                0.405929
# 16757               -0.480010
# 16758               -0.489336
# 16759               -0.489336
#
# [16760 rows x 61 columns]

# %% [markdown]
# ## Data version 3: Lasso feature selection

# %% [markdown]
# ## Normalization

# %%
scaler = preprocessing.StandardScaler()
x_train_mean=X_train_mean.values
x_train_mean_scaled = scaler.fit_transform(x_train_mean)
X_train_norm=pd.DataFrame(x_train_mean_scaled)

x_valid_mean=X_valid_mean.values
x_valid_mean_scaled = scaler.fit_transform(x_valid_mean)
X_valid_norm=pd.DataFrame(x_valid_mean_scaled)

# %% [markdown]
# ## Feature importance checking

# %% [markdown]
# # Data report

# %%
print("*"*60)
print("There are 3 set of X")
print("X_train_mean, X_valid_mean, X_test_mean")
print("-"*60)
print("Normalized version")
print("X_train_norm, X_valid_norm, X_test_norm")
print("-"*60)
print("There are 4 set of Y")
print("y_train_t1, y_train_t2, y_valid_t1, y_valid_t2")
print("*"*60)
# Out:
# ************************************************************
# There are 3 set of X
# X_train_mean, X_valid_mean, X_test_mean
# ------------------------------------------------------------
# Normalized version
# X_train_norm, X_valid_norm, X_test_norm
# ------------------------------------------------------------
# There are 4 set of Y
# y_train_t1, y_train_t2, y_valid_t1, y_valid_t2
# ************************************************************
