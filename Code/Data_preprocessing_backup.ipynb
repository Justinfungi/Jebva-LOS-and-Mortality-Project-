# %% [markdown]
# # Libraries

# %% [markdown]
# ! pip install numpy pandas sklearn

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.impute import SimpleImputer

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Import data

# %% [markdown]
# ## X

# %%
# For training the model
X_train = pd.read_csv("../X/X_train.csv" , index_col=[0], header=[0, 1, 2])

# For cross validation
X_valid = pd.read_csv("../X/X_valid.csv", index_col=[0], header=[0, 1, 2])

# For prediction
X_test = pd.read_csv("../X/X_test.csv", index_col=[0], header=[0, 1, 2])

# %% [markdown]
# ## Task 1

# %%
y_train_t1 = pd.read_csv("../Task1/Y_train.csv")
y_valid_t1 = pd.read_csv("../Task1/Y_valid.csv")

# %% [markdown]
# ## Task 2

# %%
y_train_t2 = pd.read_csv("../Task2/Y_train.csv")
y_valid_t2 = pd.read_csv("../Task2/Y_valid.csv")

# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# ## Statistics Calculation

# %%
li=[] # Find the positions of the columns with means of the particular feature after 24 hours
for i in range(47, 7488, 72):
    li.append(i)
#print(li)

dx_train = pd.DataFrame(X_train)
X_train_mean= dx_train.iloc[:,li]

dx_valid = pd.DataFrame(X_valid)
X_valid_mean= dx_valid.iloc[:,li]

dx_test = pd.DataFrame(X_test)
X_test_mean= dx_test.iloc[:,li]

X_test_mean
# Out:
# LEVEL2               alanine aminotransferase   albumin albumin ascites  \
# Aggregation Function                     mean      mean            mean
# hours_in                                   23        23              23
# 32_175413_295037                     0.000000  0.000000             0.0
# 33_176176_296681                    -0.261946  1.044231             0.0
# 42_119203_210828                    -0.251251  0.612219             0.0
# 44_181750_291554                     0.000000  0.000000             0.0
# 61_176332_252348                    -0.271571  0.000000             0.0
# ...                                       ...       ...             ...
# 99883_150755_276467                  0.000000  0.000000             0.0
# 99897_162913_266801                  0.000000  0.000000             0.0
# 99913_175989_292375                  0.000000  0.000000             0.0
# 99944_185654_221067                  0.000000  0.000000             0.0
# 99992_197084_242052                 -0.246974 -1.691847             0.0
#
# LEVEL2               albumin pleural albumin urine alkaline phosphate  \
# Aggregation Function            mean          mean               mean
# hours_in                          23            23                 23
# 32_175413_295037                 0.0           0.0           0.000000
# 33_176176_296681                 0.0           0.0          -0.138712
# 42_119203_210828                 0.0           0.0           0.117304
# 44_181750_291554                 0.0           0.0           0.000000
# 61_176332_252348                 0.0           0.0          -0.173309
# ...                              ...           ...                ...
# 99883_150755_276467              0.0           0.0           0.000000
# 99897_162913_266801              0.0           0.0           0.000000
# 99913_175989_292375              0.0           0.0           0.000000
# 99944_185654_221067              0.0           0.0           0.000000
# 99992_197084_242052              0.0           0.0          -0.443163
#
# LEVEL2               anion gap asparate aminotransferase basophils  \
# Aggregation Function      mean                      mean      mean
# hours_in                    23                        23        23
# 32_175413_295037     -0.088963                  0.000000  0.000000
# 33_176176_296681     -1.297356                 -0.259826 -0.226141
# 42_119203_210828     -0.088963                 -0.265360 -0.484272
# 44_181750_291554     -0.813998                  0.000000  0.000000
# 61_176332_252348     -0.813998                 -0.267732  1.580775
# ...                        ...                       ...       ...
# 99883_150755_276467  -0.572320                  0.000000  0.000000
# 99897_162913_266801   0.152716                  0.000000  0.000000
# 99913_175989_292375  -0.572320                  0.000000  0.000000
# 99944_185654_221067   0.636073                  0.000000 -0.742403
# 99992_197084_242052   0.152716                 -0.265360 -0.226141
#
# LEVEL2               bicarbonate  ... tidal volume set  \
# Aggregation Function        mean  ...             mean
# hours_in                      23  ...               23
# 32_175413_295037        1.019964  ...         2.536928
# 33_176176_296681        1.234293  ...         0.000000
# 42_119203_210828        0.805635  ...         0.000000
# 44_181750_291554       -0.051682  ...         0.859888
# 61_176332_252348       -0.051682  ...         0.000000
# ...                          ...  ...              ...
# 99883_150755_276467     1.448622  ...        -4.590492
# 99897_162913_266801    -0.908998  ...         0.000000
# 99913_175989_292375    -0.480340  ...         0.021368
# 99944_185654_221067    -0.051682  ...         0.000000
# 99992_197084_242052    -0.266011  ...         0.000000
#
# LEVEL2               tidal volume spontaneous total protein  \
# Aggregation Function                     mean          mean
# hours_in                                   23            23
# 32_175413_295037                    -0.353795           0.0
# 33_176176_296681                     0.000000           0.0
# 42_119203_210828                     0.000000           0.0
# 44_181750_291554                     0.079879           0.0
# 61_176332_252348                     0.000000           0.0
# ...                                       ...           ...
# 99883_150755_276467                 -0.076804           0.0
# 99897_162913_266801                  0.000000           0.0
# 99913_175989_292375                 -0.076804           0.0
# 99944_185654_221067                  0.000000           0.0
# 99992_197084_242052                  0.000000           0.0
#
# LEVEL2               total protein urine troponin-i troponin-t venous pvo2  \
# Aggregation Function                mean       mean       mean        mean
# hours_in                              23         23         23          23
# 32_175413_295037                     0.0        0.0   0.000000    0.000000
# 33_176176_296681                     0.0        0.0   0.000000   -0.495954
# 42_119203_210828                     0.0        0.0   0.000000    0.000000
# 44_181750_291554                     0.0        0.0   0.000000    0.000000
# 61_176332_252348                     0.0        0.0   0.000000    0.000000
# ...                                  ...        ...        ...         ...
# 99883_150755_276467                  0.0        0.0   0.000000    0.000000
# 99897_162913_266801                  0.0        0.0  -0.339655    0.000000
# 99913_175989_292375                  0.0        0.0   0.000000    0.000000
# 99944_185654_221067                  0.0        0.0  -0.308485    0.000000
# 99992_197084_242052                  0.0        0.0   0.000000    0.000000
#
# LEVEL2                  weight white blood cell count  \
# Aggregation Function      mean                   mean
# hours_in                    23                     23
# 32_175413_295037      0.000000               0.415254
# 33_176176_296681     -0.105634               1.310519
# 42_119203_210828     -0.517139              -0.386754
# 44_181750_291554      0.220140              -0.452033
# 61_176332_252348      0.000000              -1.020899
# ...                        ...                    ...
# 99883_150755_276467  -0.890065              -0.274846
# 99897_162913_266801  -0.370414              -0.041704
# 99913_175989_292375   0.361595              -0.218892
# 99944_185654_221067  -0.517139               0.620419
# 99992_197084_242052  -0.719808               0.424580
#
# LEVEL2               white blood cell count urine
# Aggregation Function                         mean
# hours_in                                       23
# 32_175413_295037                              0.0
# 33_176176_296681                              0.0
# 42_119203_210828                              0.0
# 44_181750_291554                              0.0
# 61_176332_252348                              0.0
# ...                                           ...
# 99883_150755_276467                           0.0
# 99897_162913_266801                           0.0
# 99913_175989_292375                           0.0
# 99944_185654_221067                           0.0
# 99992_197084_242052                           0.0
#
# [4790 rows x 104 columns]

# %% [markdown]
# ## Dealing with N/A data

# %%
# Eliminate features containing 70% 0 value
for i in X_train_mean.columns:
    if (X_train_mean[i] == 0).sum()> 12000:
        X_train_mean.drop(i, axis=1, inplace=True)

X_valid_mean = X_valid_mean[X_train_mean.columns]
X_test_mean = X_test_mean[X_train_mean.columns]

# %%
# Impute the 0 with mean

imp = SimpleImputer(missing_values=0, strategy='mean')
X_train_mean = pd.DataFrame(imp.fit_transform(X_train_mean))
X_valid_mean = pd.DataFrame(imp.fit_transform(X_valid_mean))
X_train_mean
# Out:
#              0         1         2         3         4         5         6   \
# 0     -0.254460 -1.979855 -0.318615  0.152716 -0.226618  0.003512 -1.337656
# 1     -0.256599 -0.251806 -0.422405  1.361109 -0.254291 -0.742403 -1.123327
# 2     -0.269432  0.035006 -0.367050 -0.330641 -0.271686  2.097036  0.591306
# 3     -0.138451  0.035006 -0.069442 -0.088963 -0.143050  0.003512  0.591306
# 4     -0.138451  0.035006 -0.069442 -0.813998 -0.143050  0.003512  0.376977
# ...         ...       ...       ...       ...       ...       ...       ...
# 16755 -0.138451  1.044231 -0.069442 -0.813998 -0.143050  0.290121  0.376977
# 16756 -0.138451  0.035006 -0.069442 -0.088963 -0.143050 -0.742403 -2.409302
# 16757 -0.260876  1.044231 -0.297857 -0.330641 -0.261407  0.003512  1.448622
# 16758 -0.138451  0.035006 -0.069442 -1.055677 -0.143050  0.003512  0.591306
# 16759 -0.243765  0.035006 -0.207906 -1.297356 -0.221874  0.003512  1.877280
#
#              7         8         9   ...        51        52        53  \
# 0     -0.298127  0.741842 -1.080013  ...  0.339645  0.136911 -0.809384
# 1     -0.444605  1.807475 -0.256308  ... -0.112217 -0.786812  0.359660
# 2     -0.395779 -0.416455  0.636039  ... -0.133014 -0.417323  2.697747
# 3     -0.111027 -0.323791  0.910607  ... -0.112217  0.691146 -0.482051
# 4     -0.111027  0.602846  0.430112  ...  0.103316  1.245380  1.061086
# ...         ...       ...       ...  ...       ...       ...       ...
# 16755 -0.111027 -0.184795  0.361470  ... -0.112217 -0.047833  0.266137
# 16756 -0.111027 -0.370123 -0.599519  ... -0.112217  0.321656  0.874039
# 16757 -0.151648  0.093196  0.361470  ... -0.112217 -0.602068 -0.856145
# 16758 -0.111027 -0.370123 -0.462235  ... -0.112217  1.430125  1.762512
# 16759  0.361027 -0.601782 -0.050382  ... -0.369343 -0.602068  1.107848
#
#              54        55        56        57        58        59        60
# 0      0.754975  0.336592  0.440628  0.028942 -0.042509  1.026004  0.583116
# 1     -0.089499 -0.060738 -0.049053  0.028942 -0.042509  0.008052 -0.181589
# 2      0.702221  1.199767  1.279148  0.028942 -0.042509  0.008052  0.107507
# 3     -0.617335 -0.060738 -0.049053  0.028942 -0.042509  0.008052  0.023576
# 4      0.438275  0.379751  0.440628 -1.333059 -0.317391  0.008052 -0.442708
# ...         ...       ...       ...       ...       ...       ...       ...
# 16755 -2.002789 -0.060738 -0.049053  0.028942 -0.366371  0.584864 -0.162937
# 16756  0.042444 -0.060738 -0.049053  0.028942 -0.361918  0.973702  0.405929
# 16757 -0.815234 -0.060738 -0.049053  0.028942 -0.042509 -0.472878 -0.480010
# 16758  0.372320 -0.060738 -0.049053  0.028942 -0.042509  0.781214 -0.489336
# 16759  0.174394 -1.806959 -0.817152 -0.406955 -0.366371 -0.608981 -0.489336
#
# [16760 rows x 61 columns]

# %% [markdown]
# ## Normalization

# %%
scaler = preprocessing.StandardScaler()
x_train_mean=X_train_mean.values
x_train_mean_scaled = scaler.fit_transform(x_train_mean)
X_train_norm=pd.DataFrame(x_train_mean_scaled)

x_valid_mean=X_valid_mean.values
x_valid_mean_scaled = scaler.fit_transform(x_valid_mean)
X_valid_norm=pd.DataFrame(x_valid_mean_scaled)

x_test_mean=X_test_mean.values
x_test_mean_scaled = scaler.fit_transform(x_test_mean)
X_test_norm=pd.DataFrame(x_test_mean_scaled)

# %% [markdown]
# ## Feature importance checking

# %% [markdown]
# # Data report

# %%
print("*"*60)
print("There are 3 set of X")
print("X_train_mean, X_valid_mean, X_test_mean")
print("-"*60)
print("Normalized version")
print("X_train_norm, X_valid_norm, X_test_norm")
print("-"*60)
print("There are 4 set of Y")
print("y_train_t1, y_train_t2, y_valid_t1, y_valid_t2")
print("*"*60)
